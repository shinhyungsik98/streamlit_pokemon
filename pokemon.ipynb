# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('./data/Pokemon.csv')

# %%
df
# Out:
#          #                     이름        속성      속성2   총합   체력   공격   방어  \
# 0        1              Bulbasaur     Grass   Poison  318   45   49   49
# 1        2                Ivysaur     Grass   Poison  405   60   62   63
# 2        3               Venusaur     Grass   Poison  525   80   82   83
# 3        3  VenusaurMega Venusaur     Grass   Poison  625   80  100  123
# 4        4             Charmander      Fire      NaN  309   39   52   43
# ...    ...                    ...       ...      ...  ...  ...  ...  ...
# 1099  1021            Raging Bolt  Electric   Dragon  590  125   73   91
# 1100  1022           Iron Boulder      Rock   Dragon  590   90  120   80
# 1101  1023             Iron Crown     Steel  Psychic  590   90   72  100
# 1102  1024              Terapagos    Normal      NaN  700  160  105  110
# 1103  1025              Pecharunt    Poison    Ghost  600   88   88  160
#
#       특수공격  특수방어   속도  세대  Legendary
# 0       65    65   45   1      False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          1104 non-null   int64
#  1   이름         1104 non-null   object
#  2   속성         1104 non-null   object
#  3   속성2        592 non-null    object
#  4   총합         1104 non-null   int64
#  5   체력         1104 non-null   int64
#  6   공격         1104 non-null   int64
#  7   방어         1104 non-null   int64
#  8   특수공격       1104 non-null   int64
#  9   특수방어       1104 non-null   int64
#  10  속도         1104 non-null   int64
#  11  세대         1104 non-null   int64
#  12  Legendary  1104 non-null   bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 104.7+ KB

# %%
df.nunique()
# Out:
# #            1025
# 이름           1104
# 속성             20
# 속성2            19
# 총합            224
# 체력            107
# 공격            124
# 방어            113
# 특수공격          122
# 특수방어          105
# 속도            124
# 세대              9
# Legendary       2
# dtype: int64

# %%
df['속성'].nunique()
# Out:
# 20

# %%
df['이름'].tolist()
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'VenusaurMega Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'CharizardMega Charizard X',
#  'CharizardMega Charizard Y',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'BlastoiseMega Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'BeedrillMega Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'PidgeotMega Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
# ...

# %%
df['속성'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', 'bug', 'ice'], dtype=object)

# %%
df.describe()
# Out:
#                  #        Total           HP       Attack      Defense  \
# count  1104.000000  1104.000000  1104.000000  1104.000000  1104.000000
# mean    503.437500   439.358696    70.655797    80.220109    74.507246
# std     292.665209   119.710538    26.448074    32.103379    30.715728
# min       1.000000   175.000000     1.000000     5.000000     5.000000
# 25%     254.750000   330.000000    50.000000    55.000000    50.000000
# 50%     492.500000   460.000000    68.000000    76.000000    70.000000
# 75%     749.250000   520.000000    85.000000   100.000000    90.250000
# max    1025.000000   780.000000   255.000000   190.000000   230.000000
#
#            Sp. Atk      Sp. Def        Speed   Generation
# count  1104.000000  1104.000000  1104.000000  1104.000000
# mean     72.951993    72.000906    68.994565     4.640399
# std      32.415431    27.315772    29.724086     2.598249
# min      10.000000    20.000000     5.000000     1.000000
# ...

# %%
df.hist(figsize=(10,5))
# Out:
# array([[<Axes: title={'center': '#'}>, <Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'HP'}>],
#        [<Axes: title={'center': 'Attack'}>,
#         <Axes: title={'center': 'Defense'}>,
#         <Axes: title={'center': 'Sp. Atk'}>],
#        [<Axes: title={'center': 'Sp. Def'}>,
#         <Axes: title={'center': 'Speed'}>,
#         <Axes: title={'center': 'Generation'}>]], dtype=object)

# %%
plt.figure(figsize=(10,6))
sb.pairplot(df, x_vars=['HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed','Generation'],y_vars='Total')
plt.show()

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.corr(numeric_only=True)
# Out:
#                    #     Total        HP    Attack   Defense   Sp. Atk  \
# #           1.000000  0.125245  0.136191  0.109700  0.085461  0.060601
# Total       0.125245  1.000000  0.646099  0.735895  0.629855  0.721867
# HP          0.136191  0.646099  1.000000  0.464800  0.296876  0.355803
# Attack      0.109700  0.735895  0.464800  1.000000  0.464316  0.338290
# Defense     0.085461  0.629855  0.296876  0.464316  1.000000  0.221353
# Sp. Atk     0.060601  0.721867  0.355803  0.338290  0.221353  1.000000
# Sp. Def     0.056983  0.707921  0.365849  0.266062  0.520096  0.501909
# Speed       0.056491  0.567468  0.178720  0.377604  0.017591  0.445005
# Generation  0.989787  0.073326  0.106368  0.072479  0.046853  0.021044
# Legendary   0.175234  0.475597  0.285577  0.323550  0.260338  0.388195
#
#              Sp. Def     Speed  Generation  Legendary
# #           0.056983  0.056491    0.989787   0.175234
# Total       0.707921  0.567468    0.073326   0.475597
# ...

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        512
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df['power'] = (df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']) / 6

# %%
df['power']= df['power'].round(1)

# %%
df['power']
# Out:
# 0        53.0
# 1        67.5
# 2        87.5
# 3       104.2
# 4        51.5
#         ...
# 1099     98.3
# 1100     98.3
# 1101     98.3
# 1102    116.7
# 1103    100.0
# Name: power, Length: 1104, dtype: float64

# %%
df
# Out:
#          #                   Name    Type 1   Type 2  Total   HP  Attack  \
# 0        1              Bulbasaur     Grass   Poison    318   45      49
# 1        2                Ivysaur     Grass   Poison    405   60      62
# 2        3               Venusaur     Grass   Poison    525   80      82
# 3        3  VenusaurMega Venusaur     Grass   Poison    625   80     100
# 4        4             Charmander      Fire      NaN    309   39      52
# ...    ...                    ...       ...      ...    ...  ...     ...
# 1099  1021            Raging Bolt  Electric   Dragon    590  125      73
# 1100  1022           Iron Boulder      Rock   Dragon    590   90     120
# 1101  1023             Iron Crown     Steel  Psychic    590   90      72
# 1102  1024              Terapagos    Normal      NaN    700  160     105
# 1103  1025              Pecharunt    Poison    Ghost    600   88      88
#
#       Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  power
# ...

# %%
y=df['power']

# %%
X=df.loc[:,['HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed']]

# %%
X
# Out:
#        HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      45      49       49       65       65     45
# 1      60      62       63       80       80     60
# 2      80      82       83      100      100     80
# 3      80     100      123      122      120     80
# 4      39      52       43       60       50     65
# ...   ...     ...      ...      ...      ...    ...
# 1099  125      73       91      137       89     75
# 1100   90     120       80       68      108    124
# 1101   90      72      100      122      108     98
# 1102  160     105      110      130      110     85
# 1103   88      88      160       88       88     88
#
# [1104 rows x 6 columns]

# %%
y
# Out:
# 0        53.0
# 1        67.5
# 2        87.5
# 3       104.2
# 4        51.5
#         ...
# 1099     98.3
# 1100     98.3
# 1101     98.3
# 1102    116.7
# 1103    100.0
# Name: power, Length: 1104, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
mse = ((y_test - y_pred)**2).mean()

# %%
mse
# Out:
# 0.0006875904888313599

# %%
import joblib

# %%
joblib.dump(regressor,'./model/regressor.pkl')
# Out:
# ['./model/regressor.pkl']
